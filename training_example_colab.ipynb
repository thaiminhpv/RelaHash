# %%
# !nvidia-smi
# !git clone -q https://github.com/thaiminhpv/relahash/
# %cd relahash
# Out:
# Sun Mar 19 14:08:12 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P0    29W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python main.py --ds cifar10 --nbit 64 --eval-interval 1 --beta 50 --device cuda:0
# Out:
# {'R': 59000,
#  'arch': 'RelaHash',
#  'arch_kwargs': {'batchsize': 16,
#                  'device': 'cuda:0',
#                  'freeze_weight': False,
#                  'init_method': 'M',
#                  'nbit': 64,
#                  'nclass': 10,
#                  'pretrained': True},
#  'batch_size': 16,
#  'beta': 50.0,
#  'dataset': 'cifar10',
#  'dataset_kwargs': {'crop': 224,
#                     'evaluation_protocol': 1,
#                     'norm': 2,
#                     'reset': False,
#                     'resize': 224,
#                     'separate_multiclass': False},
#  'device': 'cuda:0',
#  'epochs': 100,
#  'eval_interval': 1,
#  'logdir': 'logs/RelaHash64_cifar10_1_100_0.0001_adam_/test_420_000',
#  'm': 0.5,
#  'multiclass': False,
#  'optim': 'adam',
#  'optim_kwargs': {'betas': (0.9, 0.999),
#                   'lr': 0.0001,
#                   'momentum': 0.9,
#                   'nesterov': False,
#                   'weight_decay': 0.0005},
# ...
